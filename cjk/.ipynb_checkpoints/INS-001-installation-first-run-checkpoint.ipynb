# %% [raw]
# ---
# id: INS-001
# title: Installation and First Run
# author: Ceven Jupiter Knowles
# date: 2026-03-17
# status: active
# tags: [testing, installation]
# version: "v1.0"
# commit: 16c1b86
# branch: cjk-glitch-ministry
# pkm_tool: JupyterLab
# ---

# %% [markdown]
# # Agentic Applications | Installation & First Run
#
# ---

# %% [markdown]
# ## GitHub
#
# **Repo:** https://github.com/manuasdf/Agentic-Applications
#
# **Fork:** https://github.com/CevenJKnowles/Agentic-Applications
#
# **Clone:** SSH
#
# **Local Repo:** ~/Dev/Agentic-Applications/
#
# **Branch:** cjk-glitch-ministry
#
# **Commit Hash:** 16c1b86
#
# **Virtual Environment:** venv ~/Dev/Environments/manu-aa
#
# **Python Version:** 3.1.4.3
#
# ---

# %% [markdown]
# ## Dependencies
#
# | AI Provider SDKs | Version |
# |---|---|
# | anthropic | 0.85.0 |
# | huggingface_hub | 1.7.1 |
# | mistralai | 2.0.4 |
# | openai | 2.28.0 |
#
# | Utilities | Version |
# |---|---|
# | beautifulsoup4 | 4.14.3 |
# | pydantic | 2.12.5 |
# | python-dotenv | 1.2.2 |
# | requests | 2.32.5 |
#
# ---

# %% [markdown]
# ## System
#
# | **Hardware**  |   |   |
# |---|---|---|
# | Manufacturer:  | Acer  |   |
# | Model:  | ConceptD  | CN715-71  |
# | System Version:  | v1.09  |   |
# | Processors:  | 12 × Intel® Core™  | i7-9750H CPU @ 2.60GHz  |
# | RAM:  | 32 GiB  | *31.2 useable*  |
# | VRAM:  | 6 GB  | *(GP #2)*   |
# | Graphics Processor 1:  | Intel® UHD Graphics 630  | *integrated*  |
# | Graphics Processor 2:  | NVIDIA GeForce RTX 2060  | *discrete*  |
#
# | **Software**  |   |   |
# |---|---|---|
# | OS:  | Manjaro  | *Arch Linux*  |
# | KDE Plasma Version:  | 6.5.5  |   |
# | KDE Frameworks:  | 6.23.0  |   |
# | Qt Version:  | 6.10.2  |   |
# | Kernel Version:  | 6.12.73-1-MANJARO  | *64-bit*  |
# | Graphics Platform:  | Wayland  |   |
#
# ---

# %% [markdown]
# ## Test Scope
#
# ### Overview
#
# ### Constraints
#
# ### Method
#
# ---

# %% [markdown]
# ## Conditions
#
# - Fresh Install
# - Local input; cloud-based LLM API
# - Using all default baseline settings from original repo main
#
# ---

# %% [markdown]
# ## Outcome Summary
#
# ### Verdict
#
# ### Findings
#
# ### Errors
#
# ### Next Steps
#
# ---
